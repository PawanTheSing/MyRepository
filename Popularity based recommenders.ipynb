# %%
import numpy as np
import pandas
import csv

# %%
frame = pandas.read_csv('rating_final.csv')
cuisine = pandas.read_csv('chefmozcuisine.csv')

# %%
frame.head()    #user is customer, placeID is restaurant, other values are rating(0,1,2)
# Out:
#   userID  placeID  rating  food_rating  service_rating
# 0  U1077   135085       2            2               2
# 1  U1077   135038       2            2               1
# 2  U1077   132825       2            2               2
# 3  U1077   135060       1            2               2
# 4  U1068   135104       1            1               2

# %%
cuisine.tail()  # placeID and type of cuisine
# Out:
#      placeID       Rcuisine
# 911   132005        Seafood
# 912   132004        Seafood
# 913   132003  International
# 914   132002        Seafood
# 915   132001  Dutch-Belgian

# %%
rating_count = pandas.DataFrame(frame.groupby('placeID')['rating'].count())
rating_count.sort_values('rating',ascending=False).head()
# Out:
#          rating
# placeID
# 135085       36
# 132825       32
# 135032       28
# 135052       25
# 132834       25

# %%
rating_count
# Out:
#          rating
# placeID
# 132560        4
# 132561        4
# 132564        4
# 132572       15
# 132583        4
# 132584        6
# 132594        5
# 132608        6
# 132609        5
# 132613        6
# 132626        4
# 132630        6
# 132654        4
# 132660        5
# 132663        6
# 132665        5
# 132667        4
# 132668        3
# 132706        4
# 132715        4
# 132717        3
# 132723       12
# 132732        8
# 132733       10
# 132740        8
# 132754       13
# 132755        5
# 132766        3
# 132767        6
# 132768       10
# ...         ...
# 135054       10
# 135055        7
# 135057       15
# 135058       18
# 135059        9
# 135060       22
# 135062       21
# 135063        8
# 135064       17
# 135065        9
# 135066       12
# 135069       12
# 135070        8
# 135071        9
# 135072        8
# 135073        4
# 135074        4
# 135075       13
# 135076       13
# 135079       17
# 135080        6
# 135081       11
# 135082        9
# ...

# %%
most_rated_places = pandas.DataFrame([135085,132825, 135032, 135052, 132834], index= np.arange(5), columns=['placeID'])
summary = pandas.merge(most_rated_places, cuisine, on='placeID')
summary
# Out:
#    placeID         Rcuisine
# 0   135085        Fast_Food
# 1   132825          Mexican
# 2   135032        Cafeteria
# 3   135032     Contemporary
# 4   135052              Bar
# 5   135052  Bar_Pub_Brewery
# 6   132834          Mexican

# %% [markdown]
# # The describe method shows Mexican food is the most frequently occuring cuisine. Mexican is also the 2nd in most_rated_place.
# # This shows that it is a good candidate for recommending.

# %%
cuisine['Rcuisine'].describe()
# Out:
# count         916
# unique         59
# top       Mexican
# freq          239
# Name: Rcuisine, dtype: object
